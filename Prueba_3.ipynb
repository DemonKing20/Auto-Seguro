# %%
vehiculos = []
import random
opc = 0
nombre = ''
apellido = ''
bandera = True
precio = 0
print("Bienvenido al programa 'Auto Seguro'")
nombre = input('Escriba su nombre: ')
apellido = input('Escriba su apellido: ')
while bandera:
  print('''
  Menú
  1. Grabar vehículo
  2. Buscar vehículo
  3. Imprimir certificados
  4. Salir
  ''')
  opc = int(input('Seleccione una opción: '))
  if opc == 1:
    print('\nGrabar vehículo')
    tipo = input('Tipo: ')
    patente = input('Patente: ')
    while len(patente) != 6:
     print('La patente debe tener 6 caracteres.')
     patente = input('Patente: ')
    marca = input('Marca: ')
    while len(marca) < 2 or len(marca) > 15:
     print('La marca debe tener entre 2 y 15 caracteres.')
     marca = input('Marca: ')
    precio = input('Precio: ')
    while not precio.isnumeric() or int(precio) <= 5000000:
     print('El Precio debe ser superior a $5.000.000')
     precio = input('Precio: ')
    fecha_registro = input('Fecha de registro: ')
    nombre_dueño = input('Nombre del dueño: ')
    multas = []
    while True:
     opc = input('¿Agregar multa? (si/no): ')
     if opc == 'no':
      print('Vehiculo grabado con exito.')
      vehiculos.append(vehiculos)
      break
     elif opc == 'si':
      monto = int(input('Monto de la multa: '))
      fecha = input('Fecha de la multa: ')
      multas.append({'Monto': monto, 'Fecha': fecha})
      print('Vehiculo grabado con exito.')
      vehiculos.append(vehiculos)
     else:
      print('Opcion Invalida...')
  elif opc == 2:
    print('\nBuscar vehiculo')
    patente = input('Ingrese la patente del vehiculo: ')
    print("\nInformación del vehículo:")
    print(f"Tipo: {vehiculos[tipo]}")
    print(f"Patente: {[patente]}")
    print(f"Marca: {vehiculos[marca]}")
    print(f"Precio: ${vehiculos[precio]}")
    print(f"Nombre dueño: {vehiculos[nombre_dueño]}")
    print("Multas: ")
    for multa in vehiculos[multas]:
      print(f"Monto: ${multa[monto]} - Fecha: {multa[fecha]}")
      print(f"Fecha de registro: {vehiculos[fecha_registro]}")
      print(f"Dueño: {vehiculos[nombre_dueño]}")
    else:
        print('No se encontro ningún vehiculo con esa patente.')
  elif opc == 3:
    cert_emision = random.randint(1500, 3500)
    cert_anotaciones = random.randint(1500, 3500)
    cert_multas = random.randint(1500, 3500)
    print("\nImprimir certificados")
    print("Nombre del certificado: Emision de contaminantes")
    print("Patente del auto:", patente)
    print("Datos del dueño: ", nombre_dueño)
    print("Valor:", cert_emision)

    print("\nCertificado de Anotaciones vigentes")
    print("Nombre del certificado: Anotaciones vigentes")
    print("Patente del auto: ", patente)
    print("Datos del dueño: ", nombre_dueño)
    print('Valor: ', cert_anotaciones)

    print("Nombre del certificado: Multas")
    print("Patente del auto: ", patente)
    print("Datos del dueño: ", nombre_dueño)
    print('Valor: ', cert_multas)
    print("Multas: ")
    print("Monto: $", monto)
    print("Fecha: ", fecha)
  elif opc == 4:
    print(f'''
    Gracias {nombre} {apellido} por usar el programa "Auto Seguro".¡Vuelva Pronto!
    Version: 0.898
    ''')
    bandera = False
  else:
    print('Opcion invalida...')
    input('Pulse Enter para continuar...')
# Out:
# Bienvenido al programa 'Auto Seguro'
# Escriba su nombre: p
# Escriba su apellido: p
#
#   Menú
#   1. Grabar vehículo
#   2. Buscar vehículo
#   3. Imprimir certificados
#   4. Salir
#
# Seleccione una opción: 3
#
# Imprimir certificados
# Nombre del certificado: Emision de contaminantes
# Patente del auto: kilo89
# Datos del dueño:  kilo
# Valor: 1626
#
# Certificado de Anotaciones vigentes
# Nombre del certificado: Anotaciones vigentes
# Patente del auto:  kilo89
# Datos del dueño:  kilo
# Valor:  3066
# Nombre del certificado: Multas
# Patente del auto:  kilo89
# Datos del dueño:  kilo
# Valor:  3024
# Multas:
# Monto: $ 55000.0
# Fecha:  23-08-22
#
#   Menú
#   1. Grabar vehículo
#   2. Buscar vehículo
#   3. Imprimir certificados
#   4. Salir
#
# Seleccione una opción: 4
#
#     Gracias p p por usar el programa "Auto Seguro".¡Vuelva Pronto!
#     Version: 0.898
